# %% [markdown]
# # Imersão Mortorsports para Mulheres - AMattheis - Programação Aplicada

# %% [markdown]
# ## Importando as bibliotecas

# %%
# Importando as bibliotecas
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Importando o dataset

# %%
# Importando o dado em .csv para o código em Python através da função read_csv da biblioteca Pandas
df = pd.read_excel('setups.xlsx')

# %%
# Não limitando o número de colunas que serão visualizadas
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Conhecendo o dataframe

# %%
# Mostra as 5 primeiras linhas do nosso dataframe
df.head()
# Out:
#    Car_ID  Lap      S1      S2      S3  Time_Lap Set_Tire  Fuel  Track_Temp  \
# 0     222    1  19.993  17.123  25.657    62.773        A    30          45
# 1     222    2  17.304  16.680  24.746    58.730        A    29          45
# 2     222    3  17.511  16.447  24.266    58.224        A    27          45
# 3     222    4  16.842  16.478  24.257    57.577        A    26          45
# 4     222    1  17.165  17.195  24.460    58.820        B    30          50
#
#    Brake_Balance  Camber_FL  Camber_RL  Camber_RR  Camber_FR  Front_Conv  \
# 0             64          9        2.0        3.5        9.5           2
# 1             64          9        2.0        3.5        9.5           2
# 2             64          9        2.0        3.5        9.5           2
# 3             64          9        2.0        3.5        9.5           2
# 4             65         11        4.0        5.5       11.5           2
#
# ...

# %% [markdown]
# Sobre o que as informações que temos neste data estão relacionadas?

# %%
# Informações sobre o dataframe (ex: nome da variável, tipo da variável, valores nulos e dimensão de linhas e colunas)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Car_ID             49 non-null     int64
#  1   Lap                49 non-null     int64
#  2   S1                 47 non-null     float64
#  3   S2                 49 non-null     float64
#  4   S3                 47 non-null     float64
#  5   Time_Lap           49 non-null     float64
#  6   Set_Tire           49 non-null     object
#  7   Fuel               49 non-null     int64
#  8   Track_Temp         49 non-null     int64
#  9   Brake_Balance      49 non-null     int64
#  10  Camber_FL          49 non-null     int64
#  11  Camber_RL          49 non-null     float64
#  12  Camber_RR          49 non-null     float64
#  13  Camber_FR          49 non-null     float64
#  14  Front_Conv         49 non-null     int64
#  15  Rear_Conv          49 non-null     int64
# ...

# %% [markdown]
# As variáveis são quantitativas, qualitativas ou temos ambos os tipos?
# Temos dados nulos neste dataframe?

# %% [markdown]
# ## Correlação de Pearson

# %% [markdown]
# Mede o grau de correlação linear entre duas variáveis quantitativas.

# %%
# Calculando a correlação de Pearson entre as variáveis S3 e Time Lap
print(df.loc[:,["S3","Time_Lap"]].corr(method= "pearson"))
# Out:
#                 S3  Time_Lap
# S3        1.000000  0.482254
# Time_Lap  0.482254  1.000000

# %% [markdown]
# Existe uma correlação entre as duas variáveis? De que tipo?

# %%
# Calculando a correlação de Pearson entre as variáveis S2 e Time Lap
print(df.loc[:,["S2","Time_Lap"]].corr(method= "pearson"))
# Out:
#                 S2  Time_Lap
# S2        1.000000  0.142432
# Time_Lap  0.142432  1.000000

# %% [markdown]
# Existe uma correlação entre as duas variáveis? De que tipo?

# %%
# Calculando a correlação de Pearson entre as variáveis S1 e Time Lap
print(df.loc[:,["S1","Time_Lap"]].corr(method= "pearson"))
# Out:
#                 S1  Time_Lap
# S1        1.000000  0.099441
# Time_Lap  0.099441  1.000000

# %% [markdown]
# Existe uma correlação entre as duas variáveis? De que tipo?
# O que podemos afirmar entre as correlações dos setores em relação ao tempo de volta?

# %%
# Calculando a correlação de Pearson entre as variáveis Lap e Time Lap
print(df.loc[:,["Lap","Time_Lap"]].corr(method= "pearson"))
# Out:
#                Lap  Time_Lap
# Lap       1.000000 -0.200195
# Time_Lap -0.200195  1.000000

# %% [markdown]
# Existe uma correlação entre as duas variáveis? De que tipo?

# %%
# Calculando a correlação de Pearson entre as variáveis Rear Ride Height e Wing
print(df.loc[:,["Rear_Ride_Height","Wing"]].corr(method= "pearson"))
# Out:
#                   Rear_Ride_Height      Wing
# Rear_Ride_Height          1.000000 -0.171763
# Wing                     -0.171763  1.000000

# %% [markdown]
# Existe uma correlação entre as duas variáveis? De que tipo?
# Essa correlação faz sentido?

# %%
# Calculando a correlação de Pearson entre as variáveis Track Temp e Wing
print(df.loc[:,["Track_Temp","Wing"]].corr(method= "pearson"))
# Out:
#             Track_Temp      Wing
# Track_Temp    1.000000  0.824331
# Wing          0.824331  1.000000

# %% [markdown]
# Existe uma correlação entre as duas variáveis? De que tipo?
# Essa correlação faz sentido?

# %%
# Calculando a correlação de Pearson entre as variáveis Gurney e Wing
print(df.loc[:,["Gurney","Wing"]].corr(method= "pearson"))
# Out:
#           Gurney      Wing
# Gurney  1.000000 -0.761073
# Wing   -0.761073  1.000000

# %% [markdown]
# Existe uma correlação entre as duas variáveis? De que tipo?
# Essa correlação faz sentido?

# %%
# Plotando a matriz de correlações entre todas as variáveis usando um Heatmap ("mapa de calor").
sns.set_context(font_scale=1.9)
plt.figure(figsize=(30,26))
sns.heatmap(df.corr(), annot=True, fmt='.2f', cmap='RdBu', mask=np.triu(np.ones_like(df.corr())))
plt.show()

# %% [markdown]
# Quais hipóteses podemos levantar analisando este mapa de calor?
# LEMBRE-SE: CORRELAÇÃO NÃO IMPLICA EM CASUALIDADE!
